# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
netflix = pd.read_csv('netflix1.csv')

# %%
netflix
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# 0     United States   9/25/2021          2020  PG-13     90 min
# 1            France   9/24/2021          2021  TV-MA   1 Season
# 2     United States   9/24/2021          2021  TV-MA   1 Season
# 3            Brazil   9/22/2021          2021  TV-PG     91 min
# 4     United States   9/24/2021          1993  TV-MA    125 min
# ...             ...         ...           ...    ...        ...
# 8785         Turkey   1/17/2017          2016  TV-PG  2 Seasons
# 8786  United States   9/13/2018          2016  TV-Y7  3 Seasons
# 8787       Pakistan  12/15/2016          2012  TV-PG   1 Season
# 8788       Pakistan   6/23/2018          2016   TV-Y   1 Season
# 8789       Pakistan    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# ...                                                 ...
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
netflix.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# mapping country names to their respective continents
import pycountry_convert as pc
def get_continent(country_name):
    try:
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)
        continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        return continent_code
    except KeyError:
        return None

netflix['continent'] = netflix['country'].apply(get_continent)

# %%
# movie production by country
total_movies_by_country = netflix.groupby(['type', 'country'])['show_id'].count().reset_index()
total_movies_by_country
# Out:
#         type               country  show_id
# 0      Movie             Argentina       56
# 1      Movie             Australia       61
# 2      Movie               Austria        8
# 3      Movie            Bangladesh        3
# 4      Movie               Belgium        9
# ..       ...                   ...      ...
# 133  TV Show               Ukraine        2
# 134  TV Show  United Arab Emirates        1
# 135  TV Show        United Kingdom      251
# 136  TV Show         United States      845
# 137  TV Show               Uruguay        1
#
# [138 rows x 3 columns]

# %%
total_movies_by_country = total_movies_by_country.rename(columns={'show_id': 'count'})
total_movies_by_country
# Out:
#         type               country  count
# 0      Movie             Argentina     56
# 1      Movie             Australia     61
# 2      Movie               Austria      8
# 3      Movie            Bangladesh      3
# 4      Movie               Belgium      9
# ..       ...                   ...    ...
# 133  TV Show               Ukraine      2
# 134  TV Show  United Arab Emirates      1
# 135  TV Show        United Kingdom    251
# 136  TV Show         United States    845
# 137  TV Show               Uruguay      1
#
# [138 rows x 3 columns]

# %%
# creating two separate data frames for movies and tv shows
movies_data = total_movies_by_country[total_movies_by_country['type'] == 'Movie'].sort_values('count', ascending=False).reset_index(drop=True)
tv_shows_data = total_movies_by_country[total_movies_by_country['type'] == 'TV Show'].sort_values('count', ascending=False).reset_index(drop=True)

# %% [markdown]
# #### Exploring movie data

# %%
print(movies_data.head(10))
# Out:
#     type         country  count
# 0  Movie   United States   2395
# 1  Movie           India    976
# 2  Movie  United Kingdom    387
# 3  Movie       Not Given    257
# 4  Movie          Canada    187
# 5  Movie          France    148
# 6  Movie           Spain    129
# 7  Movie           Egypt    109
# 8  Movie         Nigeria     96
# 9  Movie          Mexico     90

# %%
# visualizing movie production by country
plt.figure(figsize=(14, 6))
plt.bar(movies_data['country'], movies_data['count'], color='dodgerblue')
plt.xticks(rotation=90)
plt.title('Movies by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.savefig('Movies.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# visualizing movie production by country while excluding the 'largest' producing countries
few_movies = movies_data[movies_data['count'] < 100]
plt.figure(figsize=(14, 6))
plt.bar(few_movies['country'], few_movies['count'], color='dodgerblue')
plt.xticks(rotation=90)
plt.title('Movies by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.savefig('Movies2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# mapping country names to their respective continents
import pycountry_convert as pc
def get_continent(country_name):
    try:
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)
        continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        return continent_code
    except KeyError:
        return None

movies_data['continent'] = movies_data['country'].apply(get_continent)

# %%
print(movies_data.head())
# Out:
#     type         country  count continent
# 0  Movie   United States   2395        NA
# 1  Movie           India    976        AS
# 2  Movie  United Kingdom    387        EU
# 3  Movie       Not Given    257      None
# 4  Movie          Canada    187        NA

# %% [markdown]
# ### Performance of continents

# %%
# countries from every continent
countries_per_continent = movies_data.groupby(['continent'])['country'].count().sort_values(ascending=False).reset_index()
countries_per_continent
# Out:
#   continent  country
# 0        EU       26
# 1        AS       24
# 2        AF       11
# 3        SA        8
# 4        NA        5
# 5        OC        2

# %%
plt.bar(countries_per_continent['continent'], countries_per_continent['country'], color = 'dodgerblue')
plt.title('Countries per Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.savefig('Countries per Continent.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# movies from every continent
movies_by_continent = movies_data.groupby(['continent'])['count'].sum().sort_values(ascending=False).reset_index()
movies_by_continent
# Out:
#   continent  count
# 0        NA   2674
# 1        AS   1726
# 2        EU    969
# 3        AF    254
# 4        SA    168
# 5        OC     76

# %%
colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700', '#C2C2F0']
plt.figure(figsize=(12, 8))
plt.pie(movies_by_continent['count'], labels=movies_by_continent['continent'], startangle=140, colors=colors)
plt.title('Movies by Continent', pad=20)
plt.axis('equal')
plt.savefig('Movies by Continent1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700', '#C2C2F0']
plt.figure(figsize=(12, 8))
plt.pie(movies_by_continent['count'], labels=movies_by_continent['continent'], autopct='%1.0f%%', startangle=140, colors=colors)
plt.title('Movies by Continent', pad=20)
plt.axis('equal')
plt.savefig('Movies by Continent2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.bar(movies_by_continent['continent'], movies_by_continent['count'], color = colors)
plt.title('Movies by Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.savefig('Movies by Continent3.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Performamnce of Countries per continent

# %%
african_movies = movies_data[movies_data['continent'] == 'AF']
african_movies
# Out:
#      type       country  count continent
# 7   Movie         Egypt    109        AF
# 8   Movie       Nigeria     96        AF
# 24  Movie  South Africa     35        AF
# 53  Movie         Ghana      4        AF
# 55  Movie         Kenya      4        AF
# 65  Movie     Mauritius      1        AF
# 67  Movie       Somalia      1        AF
# 70  Movie       Namibia      1        AF
# 71  Movie    Mozambique      1        AF
# 77  Movie      Cameroon      1        AF
# 78  Movie      Zimbabwe      1        AF

# %%
plt.figure(figsize=(14, 6))
plt.bar(african_movies['country'], african_movies['count'], color = 'goldenrod')
plt.xticks(rotation=90)
plt.title('Movies by African Countries')
plt.xlabel('Africa')
plt.ylabel('Count')
plt.savefig('African Movies.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
north_america_movies = movies_data[movies_data['continent'] == 'NA']
plt.figure(figsize=(14, 6))
plt.bar(north_america_movies['country'], north_america_movies['count'], color = 'brown')
plt.title('Movies by North American Countries')
plt.xlabel('North America')
plt.ylabel('Count')
plt.savefig('North American Movies.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
asia_movies = movies_data[movies_data['continent'] == 'AS']
plt.figure(figsize=(14, 6))
plt.bar(asia_movies['country'], asia_movies['count'], color = 'coral')
plt.xticks(rotation=90)
plt.title('Movies by Asian Countries')
plt.xlabel('Asia')
plt.ylabel('Count')
plt.savefig('Asian Movies.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
europe_movies = movies_data[movies_data['continent'] == 'EU']
plt.figure(figsize=(14, 6))
plt.bar(europe_movies['country'], europe_movies['count'], color = 'teal')
plt.xticks(rotation=90)
plt.title('Movies by European Countries')
plt.xlabel('Europe')
plt.ylabel('Count')
plt.savefig('European Movies.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
south_america_movies = movies_data[movies_data['continent'] == 'SA']
plt.figure(figsize=(14, 6))
plt.bar(south_america_movies['country'], south_america_movies['count'], color = 'orangered')
plt.title('Movies by South American Countries')
plt.xlabel('South America')
plt.ylabel('Count')
plt.savefig('South America Movies.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
oceania_movies = movies_data[movies_data['continent'] == 'OC']
plt.figure(figsize=(14, 6))
plt.bar(oceania_movies['country'], oceania_movies['count'], color = 'hotpink')
plt.title('Movies by Oceania Countries')
plt.xlabel('Oceania')
plt.ylabel('Count')
plt.savefig('Oceania Movies.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### World Map

# %%
import geopandas as gpd
world = gpd.read_file("countries/ne_110m_admin_0_countries.shp")

# %%
world.head()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE TLC                        ADMIN  ...  \
# 0         0      2  Sovereign country   1                         Fiji  ...
# 1         0      2  Sovereign country   1  United Republic of Tanzania  ...
# 2         0      2      Indeterminate   1               Western Sahara  ...
# 3         0      2  Sovereign country   1                       Canada  ...
# 4         1      2            Country   1     United States of America  ...
#
#       FCLASS_TR     FCLASS_ID     FCLASS_PL FCLASS_GR  FCLASS_IT  \
# 0          None          None          None      None       None
# 1          None          None          None      None       None
# 2  Unrecognized  Unrecognized  Unrecognized      None       None
# 3          None          None          None      None       None
# 4          None          None          None      None       None
#
#       FCLASS_NL FCLASS_SE  FCLASS_BD FCLASS_UA  \
# 0          None      None       None      None
# 1          None      None       None      None
# 2  Unrecognized      None       None      None
# 3          None      None       None      None
# 4          None      None       None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((180 -16.06713, 180 -16.55522, ...
# 1  POLYGON ((33.90371 -0.95, 34.07262 -1.05982, 3...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84 49, -122.97421 49.0025...
# 4  MULTIPOLYGON (((-122.84 49, -120 49, -117.0312...
#
# [5 rows x 169 columns]

# %%
# checking for contradictions in country naming conventions
world.head(10)['SOVEREIGNT']
# Out:
# 0                           Fiji
# 1    United Republic of Tanzania
# 2                 Western Sahara
# 3                         Canada
# 4       United States of America
# 5                     Kazakhstan
# 6                     Uzbekistan
# 7               Papua New Guinea
# 8                      Indonesia
# 9                      Argentina
# Name: SOVEREIGNT, dtype: object

# %%
movies_data.head(10)['country']
# Out:
# 0     United States
# 1             India
# 2    United Kingdom
# 3         Not Given
# 4            Canada
# 5            France
# 6             Spain
# 7             Egypt
# 8           Nigeria
# 9            Mexico
# Name: country, dtype: object

# %% [markdown]
# * There are differences in some names such as that of the USA

# %%
# harmonizing the contradictions in names
world_countries = set(world['SOVEREIGNT'].unique())
movies_countries = set(movies_data['country'].unique())

# countries in movies_data but not in world
unmatched_movies = movies_countries - world_countries

# countries in world but not in movies_data
unmatched_world = world_countries - movies_countries

print("Countries in movies_data but not in world dataset:")
print(unmatched_movies)

print("\nCountries in world dataset but not in movies_data:")
print(unmatched_world)
# Out:
# Countries in movies_data but not in world dataset:
# {'United States', 'Singapore', 'Hong Kong', 'Mauritius', 'Serbia', 'Not Given', 'Soviet Union', 'Czech Republic', 'West Germany'}
#
# Countries in world dataset but not in movies_data:
# {'Haiti', 'Gambia', 'Myanmar', 'Trinidad and Tobago', 'Libya', 'Afghanistan', 'Liberia', 'Sudan', 'Dominican Republic', 'Republic of the Congo', 'Sri Lanka', 'Mali', 'Fiji', 'Iraq', 'Gabon', 'Cuba', 'Honduras', 'The Bahamas', 'United States of America', 'South Sudan', 'Suriname', 'Moldova', 'Belize', 'Latvia', 'North Macedonia', 'United Republic of Tanzania', 'Lesotho', 'Zambia', 'Botswana', 'Panama', 'Mauritania', 'Qatar', 'Oman', 'Madagascar', 'Senegal', 'Eritrea', 'Equatorial Guinea', 'Bhutan', 'Democratic Republic of the Congo', 'Guinea-Bissau', 'Kyrgyzstan', 'Azerbaijan', 'Turkmenistan', 'Uganda', 'Slovakia', 'Republic of Serbia', 'Brunei', 'Algeria', 'North Korea', 'Rwanda', 'Vanuatu', 'Central African Republic', 'Angola', 'Estonia', 'Togo', 'Djibouti', 'Niger', 'Mongolia', 'Bosnia and Herzegovina', 'Armenia', 'Antarctica', 'Cyprus', 'Kazakhstan', 'Benin', 'Belarus', 'Chad', 'Morocco', 'Northern Cyprus', 'Tajikistan', 'Nepal', 'Solomon Islands', 'Ethiopia', 'Lithuania', 'Nicaragua', 'Burundi', 'Malawi', 'Luxembourg', 'Ecuador', 'Laos', 'Guinea', 'Kosovo', 'Papua New Guinea', 'eSwatini', 'El Salvador', 'Yemen', 'Ukraine', 'Bolivia', 'Czechia', 'Montenegro', 'East Timor', 'Western Sahara', 'Guyana', 'Ivory Coast', 'Uzbekistan', 'Tunisia', 'Costa Rica', 'Sierra Leone', 'Burkina Faso', 'Jordan', 'Somaliland', 'Albania'}

# %%
country_name_mapping = {
    'United States': 'United States of America',
    'Czech Republic': 'Czechia',
    'West Germany': 'Germany',
    'Serbia': 'Republic of Serbia',
    'Soviet Union': 'Russia',
    'Not Given': None,
    'Hong Kong': 'China',
}

# applying the mapping
movies_data['country'] = movies_data['country'].replace(country_name_mapping)

# %%
movies_data.head(10)['country']
# Out:
# 0    United States of America
# 1                       India
# 2              United Kingdom
# 3                        None
# 4                      Canada
# 5                      France
# 6                       Spain
# 7                       Egypt
# 8                     Nigeria
# 9                      Mexico
# Name: country, dtype: object

# %% [markdown]
# #### Countries with and without a movie on netflix

# %%
# creating a new column in world to indicate whether a country has a movie
world['has_movie'] = world['SOVEREIGNT'].isin(movies_data['country'])

# %%
# visualizing the countries with and without movies on netflix
plt.figure(figsize=(15, 10))
base = world.plot(color='lightgrey', edgecolor='black')
world[world['has_movie']].plot(ax=base, color='red') # using red which is the custom color for netflix
plt.title('Countries with Movies on Netflix', fontsize=10, fontweight='bold')
plt.axis('off')
plt.savefig('map1.png', dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Considering number of movies produced by different countries

# %%
world_merged = world.merge(movies_data, left_on='ADMIN', right_on='country', how='left')

# %%
plt.figure(figsize=(20, 15))
world_merged.plot(column='count', 
                  cmap='OrRd',
                  legend=True,
                  missing_kwds={"color": "lightgrey"},
                  edgecolor='black', 
                  linewidth=0.5)

plt.title('Number of Movies per Country on Netflix', fontsize=10, fontweight='bold')
plt.axis('off')
plt.savefig('map2.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
# scaling the count to improve color contrast
plt.figure(figsize=(20, 12))
world_merged['log_count'] = np.log1p(world_merged['count'])
world_merged.plot(column='log_count', 
                  cmap='OrRd', 
                  legend=True, 
                  vmin=0, vmax=8,
                  missing_kwds={"color": "lightgrey"},
                  edgecolor='black', 
                  linewidth=0.5)

plt.title('Number of Movies per Country on Netflix', fontsize=10, fontweight='bold', pad=20)
plt.axis('off')
plt.savefig('map3.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
# resizing the legend
plt.figure(figsize=(20, 12))
world_merged['log_count'] = np.log1p(world_merged['count'])
ax = world_merged.plot(column='log_count', 
                       cmap='OrRd', 
                       legend=False, 
                       vmin=0, vmax=8, 
                       missing_kwds={"color": "lightgrey"},
                       edgecolor='black', 
                       linewidth=0.5)

sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=0, vmax=8))
sm._A = []
cbar = plt.colorbar(sm, ax=ax, fraction=0.02, pad=0.04)  
cbar.set_label('(Log)', fontsize=6)
plt.title('Number of Movies per Country on Netflix', fontsize=10, fontweight='bold', pad=15)
plt.axis('off')
plt.savefig('map4.png', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Most popular movies genres by continent and country

# %%
movie_data = netflix[netflix['type'] == 'Movie'].reset_index(drop=True)
tv_show_data = netflix[netflix['type'] == 'TV Show'].reset_index(drop=True)

# %%
genre_popularity = movie_data.groupby('listed_in')['show_id'].count().sort_values(ascending=False)
genre_popularity.head()
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Name: show_id, dtype: int64

# %%
movie_genres = movie_data.groupby(['country', 'listed_in'])['show_id'].count().sort_values(ascending=False).reset_index()
movie_genres
# Out:
#             country                                         listed_in  show_id
# 0     United States                                     Documentaries      269
# 1     United States                                   Stand-Up Comedy      216
# 2             India            Comedies, Dramas, International Movies      124
# 3             India                      Dramas, International Movies      122
# 4     United States                Children & Family Movies, Comedies      122
# ...             ...                                               ...      ...
# 1277       Malaysia  Dramas, Independent Movies, International Movies        1
# 1278       Malaysia     Dramas, International Movies, Romantic Movies        1
# 1279       Malaysia               Horror Movies, International Movies        1
# 1280      Mauritius                Children & Family Movies, Comedies        1
# 1281       Zimbabwe   Comedies, International Movies, Romantic Movies        1
#
# [1282 rows x 3 columns]

# %%
# splitting genres
movie_data['genres_split'] = movie_data['listed_in'].str.split(', ')

# exploding the genres into individual rows
movie_data_exploded = movie_data.explode('genres_split')

# %%
movie_data_exploded.head()
# Out:
#   show_id   type                             title         director  \
# 0      s1  Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1     s14  Movie  Confessions of an Invisible Girl    Bruno Garotti
# 1     s14  Movie  Confessions of an Invisible Girl    Bruno Garotti
# 2      s8  Movie                           Sankofa     Haile Gerima
# 2      s8  Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating duration  \
# 0  United States  9/25/2021          2020  PG-13   90 min
# 1         Brazil  9/22/2021          2021  TV-PG   91 min
# 1         Brazil  9/22/2021          2021  TV-PG   91 min
# 2  United States  9/24/2021          1993  TV-MA  125 min
# 2  United States  9/24/2021          1993  TV-MA  125 min
#
#                                           listed_in continent  \
# 0                                     Documentaries        NA
# 1                Children & Family Movies, Comedies        SA
# 1                Children & Family Movies, Comedies        SA
# 2  Dramas, Independent Movies, International Movies        NA
# 2  Dramas, Independent Movies, International Movies        NA
#
#                genres_split
# 0             Documentaries
# 1  Children & Family Movies
# 1                  Comedies
# 2                    Dramas
# 2        Independent Movies

# %%
# total movie genres
unique_genre_total = movie_data_exploded['genres_split'].unique()
unique_genre_total
# Out:
# array(['Documentaries', 'Children & Family Movies', 'Comedies', 'Dramas',
#        'Independent Movies', 'International Movies', 'Music & Musicals',
#        'Movies', 'Romantic Movies', 'Horror Movies', 'Sci-Fi & Fantasy',
#        'Thrillers', 'Action & Adventure', 'Classic Movies',
#        'Anime Features', 'Sports Movies', 'Cult Movies',
#        'Stand-Up Comedy', 'Faith & Spirituality', 'LGBTQ Movies'],
#       dtype=object)

# %%
len(unique_genre_total)
# Out:
# 20

# %%
# count of genres by continent
genre_count_by_continent = movie_data_exploded.groupby(['continent', 'genres_split']).size().sort_values(ascending=False).reset_index(name='count')
genre_count_by_continent.head(10)
# Out:
#   continent              genres_split  count
# 0        AS      International Movies   1493
# 1        AS                    Dramas    968
# 2        NA                    Dramas    761
# 3        NA                  Comedies    693
# 4        EU      International Movies    567
# 5        AS                  Comedies    547
# 6        NA             Documentaries    502
# 7        EU                    Dramas    398
# 8        NA  Children & Family Movies    390
# 9        NA        Independent Movies    379

# %%
# count of genres by country
genre_count_by_country = movie_data_exploded.groupby(['country','genres_split']).size().sort_values(ascending=False).reset_index(name='count')
genre_count_by_country.head(10)
# Out:
#          country              genres_split  count
# 0          India      International Movies    861
# 1  United States                    Dramas    679
# 2          India                    Dramas    655
# 3  United States                  Comedies    616
# 4  United States             Documentaries    457
# 5  United States  Children & Family Movies    347
# 6  United States        Independent Movies    331
# 7          India                  Comedies    328
# 8  United States        Action & Adventure    323
# 9  United States                 Thrillers    233

# %%
import seaborn as sns

# filtering for top three genres per continent
top_genres_by_continent = (
    genre_count_by_continent
    .sort_values(['continent', 'count'], ascending=[True, False])
    .groupby('continent')
    .head(3)
    .reset_index(drop=True)
)

top_genres = top_genres_by_continent['genres_split'].unique()
# visualizing the most popular movie genres by continent
plt.figure(figsize=(10, 6))
sns.barplot(data=top_genres_by_continent, x='continent', y='count', hue='genres_split', palette='Paired', hue_order=top_genres)
plt.title('Most Popular Genres from Every Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.legend(title='Genre')
plt.savefig('genre_by_continent1.png', dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### Note: Seaborn is plotting 4 bars for every continent yet I want only the top three. That needs to be rectified

# %%
# count of genres by location
genre_count_by_location = movie_data_exploded.groupby(['continent', 'country', 'genres_split']).size().sort_values(ascending=False).reset_index(name='count')
genre_count_by_location
# Out:
#     continent        country              genres_split  count
# 0          AS          India      International Movies    861
# 1          NA  United States                    Dramas    679
# 2          AS          India                    Dramas    655
# 3          NA  United States                  Comedies    616
# 4          NA  United States             Documentaries    457
# ..        ...            ...                       ...    ...
# 663        EU         Russia        Action & Adventure      1
# 664        NA         Mexico            Classic Movies      1
# 665        AS       Thailand  Children & Family Movies      1
# 666        EU         Norway             Horror Movies      1
# 667        AF       Cameroon                    Dramas      1
#
# [668 rows x 4 columns]

# %%
# filter for africa
africa_data = genre_count_by_location[genre_count_by_location['continent'] == 'AF']
top_genre_africa = africa_data.loc[africa_data.groupby('country')['count'].idxmax()]

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=top_genre_africa, x='country', y='count', hue='genres_split', palette='viridis')
plt.title('Most Popular Movie Genre in African Countries')
plt.xlabel('Country')
plt.ylabel('Genre Count')
#plt.xticks(rotation=90)
plt.savefig('top_genre_africa.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
# filter for north america
na_data = genre_count_by_location[genre_count_by_location['continent'] == 'NA']
top_genre_na = na_data.loc[na_data.groupby('country')['count'].idxmax()]

# plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=top_genre_na, x='country', y='count', hue='genres_split', palette='viridis')
plt.title('Most Popular Movie Genre in North American Countries')
plt.xlabel('Country')
plt.ylabel('Genre Count')
plt.savefig('top_genre_na.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
# filter for south america
sa_data = genre_count_by_location[genre_count_by_location['continent'] == 'SA']
top_genre_sa = sa_data.loc[sa_data.groupby('country')['count'].idxmax()]

# plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=top_genre_sa, x='country', y='count', hue='genres_split', palette='viridis')
plt.title('Most Popular Movie Genre in South American Countries')
plt.xlabel('Country')
plt.ylabel('Genre Count')
plt.savefig('top_genre_sa.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
# filter for europe
eu_data = genre_count_by_location[genre_count_by_location['continent'] == 'EU']
top_genre_eu = eu_data.loc[eu_data.groupby('country')['count'].idxmax()]

# plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=top_genre_eu, x='country', y='count', hue='genres_split', palette='viridis')
plt.title('Most Popular Movie Genre in European Countries')
plt.xlabel('Country')
plt.ylabel('Genre Count')
plt.xticks(rotation=90)
plt.savefig('top_genre_eu.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
# filter for asia
asia_data = genre_count_by_location[genre_count_by_location['continent'] == 'AS']
top_genre_asia = asia_data.loc[asia_data.groupby('country')['count'].idxmax()]

# plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=top_genre_asia, x='country', y='count', hue='genres_split', palette='viridis')
plt.title('Most Popular Movie Genre in Asian Countries')
plt.xlabel('Country')
plt.ylabel('Genre Count')
plt.xticks(rotation=90)
plt.savefig('top_genre_asia.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
# filter for oceania
oc_data = genre_count_by_location[genre_count_by_location['continent'] == 'OC']
top_genre_oc = oc_data.loc[oc_data.groupby('country')['count'].idxmax()]

# plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=top_genre_oc, x='country', y='count', hue='genres_split', palette='viridis')
plt.title('Most Popular Movie Genre in Oceania Countries')
plt.xlabel('Country')
plt.ylabel('Genre Count')
plt.savefig('top_genre_oc.png', dpi=400, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Exploring tv show data

# %%
print(tv_shows_data.head())
# Out:
#       type         country  count
# 0  TV Show   United States    845
# 1  TV Show        Pakistan    350
# 2  TV Show  United Kingdom    251
# 3  TV Show           Japan    172
# 4  TV Show     South Korea    165

# %%
plt.figure(figsize=(14, 6))
plt.bar(tv_shows_data['country'], tv_shows_data['count'], color='lightgreen')
plt.xticks(rotation=90)
plt.title('TV Shows by Country')
plt.xlabel('Country')
plt.savefig('TV Shows.png', dpi=300, bbox_inches='tight')
plt.ylabel('Count')
# Out:
# Text(133.09722222222223, 0.5, 'Count')

# %% [markdown]
# #### More Insights

# %%
netflix['release_year'].hist(bins=20, color='purple', edgecolor='black')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.title('Movies and TV Shows by Release Year')
plt.grid(False)
plt.savefig('Release Year.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
netflix['date_added'] = pd.to_datetime(netflix['date_added'])
added_over_time = netflix.groupby([netflix['date_added'].dt.year, 'type'])['show_id'].count().unstack()
added_over_time.plot(kind='line', figsize=(10, 6))
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Number of Movies and TV Shows Added Over Time')
plt.savefig('Added.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
netflix_movies = netflix[netflix['type'] == 'Movie'].copy()  # Create a copy to avoid warnings
netflix_movies.loc[:, 'duration'] = netflix_movies['duration'].str.replace(' min', '').astype(int)

netflix_movies['duration'].hist(bins=20, color='orange', edgecolor='black')
plt.xlabel('Duration (minutes)')
plt.ylabel('Count')
plt.title('Movie Durations')
plt.grid(False)
plt.savefig('Movie Durations.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# visualizing the most frequently occurring genres in the dataset
from wordcloud import WordCloud

all_genres = ' '.join(netflix['listed_in'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(all_genres)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Netflix Genres', fontsize=15)
plt.show()

# %%
# creating a word cloud from genres but for movies alone
movie_data = netflix[netflix['type'] == 'Movie']
movie_genres = ' '.join(movie_data['listed_in'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(movie_genres)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Netflix Movie Genres', fontsize=15)
plt.savefig('Movie Genres.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# creating a word cloud from genres but for tv shows alone
tv_show_data = netflix[netflix['type'] == 'TV Show']
tv_show_genres = ' '.join(tv_show_data['listed_in'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(tv_show_genres)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Netflix TV Show Genres', fontsize=15)
plt.savefig('TV Genre.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# distribution of movie durations to reveal common lengths
movie_data = netflix[netflix['type'] == 'Movie'].copy()

movie_data['duration'] = movie_data['duration'].str.replace(' min', '', regex=False)  # Remove ' min'
movie_data = movie_data[movie_data['duration'].str.isnumeric()] 
movie_data['duration'] = movie_data['duration'].astype(int)

# Plot histogram of movie durations
plt.hist(movie_data['duration'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Movie Durations', fontsize=15)
plt.xlabel('Duration (minutes)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.savefig('Duration Distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# variation of duration with content rating
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='rating', y='duration', data=movie_data)
plt.title('Movie Duration by Rating', fontsize=15)
plt.xticks(rotation=45)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Duration (minutes)', fontsize=12)
plt.savefig('Duration by Rating.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# movie production throughout the years
netflix.groupby(["release_year"])["title"].count().plot.line(
    x="release_year",
    y="title",
);
plt.title("Number of Movies against Release Years");
plt.ylabel("Number of Movies");

# %%
netflix
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# 0     United States 2021-09-25          2020  PG-13     90 min
# 1            France 2021-09-24          2021  TV-MA   1 Season
# 2     United States 2021-09-24          2021  TV-MA   1 Season
# 3            Brazil 2021-09-22          2021  TV-PG     91 min
# 4     United States 2021-09-24          1993  TV-MA    125 min
# ...             ...        ...           ...    ...        ...
# 8785         Turkey 2017-01-17          2016  TV-PG  2 Seasons
# 8786  United States 2018-09-13          2016  TV-Y7  3 Seasons
# 8787       Pakistan 2016-12-15          2012  TV-PG   1 Season
# 8788       Pakistan 2018-06-23          2016   TV-Y   1 Season
# 8789       Pakistan 2018-06-07          2016  TV-Y7   1 Season
#
#                                               listed_in continent
# 0                                         Documentaries        NA
# 1     Crime TV Shows, International TV Shows, TV Act...        EU
# 2                    TV Dramas, TV Horror, TV Mysteries        NA
# 3                    Children & Family Movies, Comedies        SA
# 4      Dramas, Independent Movies, International Movies        NA
# ...                                                 ...       ...
# 8785                  International TV Shows, TV Dramas        AS
# 8786                                           Kids' TV        NA
# 8787  International TV Shows, Romantic TV Shows, TV ...        AS
# 8788                                           Kids' TV        AS
# 8789                                           Kids' TV        AS
#
# [8790 rows x 11 columns]

# %%
netflix["Continent"] = netflix['country'].apply(get_continent)
netflix
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# 0     United States 2021-09-25          2020  PG-13     90 min
# 1            France 2021-09-24          2021  TV-MA   1 Season
# 2     United States 2021-09-24          2021  TV-MA   1 Season
# 3            Brazil 2021-09-22          2021  TV-PG     91 min
# 4     United States 2021-09-24          1993  TV-MA    125 min
# ...             ...        ...           ...    ...        ...
# 8785         Turkey 2017-01-17          2016  TV-PG  2 Seasons
# 8786  United States 2018-09-13          2016  TV-Y7  3 Seasons
# 8787       Pakistan 2016-12-15          2012  TV-PG   1 Season
# 8788       Pakistan 2018-06-23          2016   TV-Y   1 Season
# 8789       Pakistan 2018-06-07          2016  TV-Y7   1 Season
#
#                                               listed_in continent Continent
# 0                                         Documentaries        NA        NA
# 1     Crime TV Shows, International TV Shows, TV Act...        EU        EU
# 2                    TV Dramas, TV Horror, TV Mysteries        NA        NA
# 3                    Children & Family Movies, Comedies        SA        SA
# 4      Dramas, Independent Movies, International Movies        NA        NA
# ...                                                 ...       ...       ...
# 8785                  International TV Shows, TV Dramas        AS        AS
# 8786                                           Kids' TV        NA        NA
# 8787  International TV Shows, Romantic TV Shows, TV ...        AS        AS
# 8788                                           Kids' TV        AS        AS
# 8789                                           Kids' TV        AS        AS
#
# [8790 rows x 12 columns]

# %%
from datetime import datetime
netflix["Year_added"] = netflix["date_added"].apply(lambda x: x.strftime("%Y"))
netflixYeardf = netflix.groupby(["Continent", "country", "Year_added", "type"])["show_id"].count().to_frame()
netflixYeardf
# Out:
#                                         show_id
# Continent country   Year_added type
# AF        Cameroon  2021       Movie          1
#           Egypt     2018       Movie          1
#                                TV Show        1
#                     2019       Movie         51
#                                TV Show        8
# ...                                         ...
# SA        Uruguay   2020       Movie          3
#                     2021       Movie          1
#                                TV Show        1
#           Venezuela 2017       Movie          1
#                     2018       Movie          1
#
# [540 rows x 1 columns]

# %%
import seaborn as sns
def continent_plot(continent, df):
    plot = sns.boxplot(
        data=netflixYeardf.loc[continent],
        y="country",
        x="show_id",
        orient="h",
        hue="type",
        width=0.6,
    ).set_title("{} Countries".format(continent));
    plt.figure(figsize=(50,70))
    return plot

# %%
continent_plot("AF", netflixYeardf)
# Out:
# Text(0.5, 1.0, 'AF Countries')
