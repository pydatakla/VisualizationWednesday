# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("electricity_data.csv")
df.head()
# Out:
#   Country Name Country Code                              Series Name  \
# 0        Kenya          KEN  Access to electricity (% of population)
# 1        Kenya          KEN              Electricity net consumption
# 2        Kenya          KEN               Electricity net generation
# 3       Uganda          UGA  Access to electricity (% of population)
# 4       Uganda          UGA              Electricity net consumption
#
#       Series Code 1993 [YR1993]      1994 [YR1994]     1995 [YR1995]  \
# 0  EG.ELC.ACCS.ZS          10.9   3.47343683242798  5.42734336853027
# 1     CC.ELEC.CON       3.28507              3.311             3.455
# 2     CC.ELEC.GEN       3.57807              3.616             4.035
# 3  EG.ELC.ACCS.ZS            ..  0.533898532390594               6.8
# 4     CC.ELEC.CON      0.785296           0.822545          0.856857
#
#       1996 [YR1996]     1997 [YR1997]     1998 [YR1998]  ...  \
# 0  7.37853050231934  9.32631778717041              14.5  ...
# ...

# %%
df_global = pd.read_csv("data.csv")
df_global.head()
# Out:
#   Country Name Country Code                              Series Name  \
# 0  Afghanistan          AFG  Access to electricity (% of population)
# 1  Afghanistan          AFG              Electricity net consumption
# 2  Afghanistan          AFG               Electricity net generation
# 3      Albania          ALB  Access to electricity (% of population)
# 4      Albania          ALB              Electricity net consumption
#
#       Series Code     2019 [YR2019]
# 0  EG.ELC.ACCS.ZS  97.6999969482422
# 1     CC.ELEC.CON           5.91309
# 2     CC.ELEC.GEN           1.06269
# 3  EG.ELC.ACCS.ZS               100
# 4     CC.ELEC.CON           6.52798

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   26 non-null     object
#  1   Country Code   24 non-null     object
#  2   Series Name    24 non-null     object
#  3   Series Code    24 non-null     object
#  4   1993 [YR1993]  24 non-null     object
#  5   1994 [YR1994]  24 non-null     object
#  6   1995 [YR1995]  24 non-null     object
#  7   1996 [YR1996]  24 non-null     object
#  8   1997 [YR1997]  24 non-null     object
#  9   1998 [YR1998]  24 non-null     object
#  10  1999 [YR1999]  24 non-null     object
#  11  2000 [YR2000]  24 non-null     object
#  12  2001 [YR2001]  24 non-null     object
#  13  2002 [YR2002]  24 non-null     object
#  14  2003 [YR2003]  24 non-null     object
#  15  2004 [YR2004]  24 non-null     object
#  16  2005 [YR2005]  24 non-null     object
# ...

# %%
# convert yearly columns to numeric
yearly_columns = [col for col in df.columns if '[YR' in col]
for col in yearly_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
# convert yearly columns to numeric
yearly_columns = [col for col in df_global.columns if '[YR' in col]
for col in yearly_columns:
    df_global[col] = pd.to_numeric(df_global[col], errors='coerce')

# %%
df.rename(columns={'Country Name':'country_name', 'Country Code':'country_code', 'Series Name':'series_name', 'Series Code':'series_code', 
                   '1993 [YR1993]':'1993', '1994 [YR1994]':'1994', '1995 [YR1995]':'1995', '1996 [YR1996]':'1996', '1997 [YR1997]':'1997', 
                   '1998 [YR1998]':'1998', '1999 [YR1999]':'1999', '2000 [YR2000]':'2000', '2001 [YR2001]':'2001', '2002 [YR2002]':'2002', 
                   '2003 [YR2003]':'2003', '2004 [YR2004]':'2004', '2005 [YR2005]':'2005', '2006 [YR2006]':'2006','2007 [YR2007]':'2007',
                   '2008 [YR2008]':'2008','2009 [YR2009]':'2009', '2010 [YR2010]':'2010', '2011 [YR2011]':'2011', '2012 [YR2012]':'2012', 
                   '2013 [YR2013]':'2013', '2014 [YR2014]':'2014', '2015 [YR2015]':'2015', '2016 [YR2016]':'2016', '2017 [YR2017]':'2017', 
                   '2018 [YR2018]':'2018', '2019 [YR2019]':'2019'}, inplace=True)

# %%
df_global.rename(columns={'Country Name':'country_name', 'Country Code':'country_code', 'Series Name':'series_name', 'Series Code':'series_code', 
                   '2019 [YR2019]':'2019'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_name  26 non-null     object
#  1   country_code  24 non-null     object
#  2   series_name   24 non-null     object
#  3   series_code   24 non-null     object
#  4   1993          16 non-null     float64
#  5   1994          17 non-null     float64
#  6   1995          17 non-null     float64
#  7   1996          17 non-null     float64
#  8   1997          18 non-null     float64
#  9   1998          19 non-null     float64
#  10  1999          19 non-null     float64
#  11  2000          21 non-null     float64
#  12  2001          21 non-null     float64
#  13  2002          21 non-null     float64
#  14  2003          21 non-null     float64
#  15  2004          21 non-null     float64
#  16  2005          21 non-null     float64
# ...

# %%
df = df[['series_name', 'country_name', '2019']]
#'1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', 
'2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
# Out:
# ('2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018')

# %%
df_global = df_global[['series_name', 'country_name', '2019']]

# %%
df1 = df.query("country_name != 'South Sudan' & country_name != 'Congo, Dem. Rep.'")
serie1 = df1.query("series_name == 'Access to electricity (% of population)'").reset_index(drop=True)
years = [col for col in df.columns if col.isnumeric()] 
df2 = pd.melt(serie1, id_vars=["country_name"], value_vars=years, 
                  var_name="year", value_name="percentage")
df2
# Out:
#   country_name  year  percentage
# 0        Kenya  2019   69.699997
# 1       Uganda  2019   41.299999
# 2       Rwanda  2019   40.368607
# 3      Burundi  2019   11.356528
# 4     Tanzania  2019   37.659687
# 5      Somalia  2019   49.200001

# %%
serie_global = df_global.query("series_name == 'Access to electricity (% of population)'").reset_index(drop=True)
years = [col for col in df_global.columns if col.isnumeric()] 
df_global1 = pd.melt(serie_global, id_vars=["country_name"], value_vars=years, 
                  var_name="year", value_name="percentage")
df_global1
# Out:
#               country_name  year  percentage
# 0              Afghanistan  2019   97.699997
# 1                  Albania  2019  100.000000
# 2                  Algeria  2019   99.500000
# 3           American Samoa  2019         NaN
# 4                  Andorra  2019  100.000000
# ..                     ...   ...         ...
# 215  Virgin Islands (U.S.)  2019  100.000000
# 216     West Bank and Gaza  2019  100.000000
# 217            Yemen, Rep.  2019   72.751076
# 218                 Zambia  2019   43.000000
# 219               Zimbabwe  2019   46.781475
#
# [220 rows x 3 columns]

# %%
df_global1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_name  220 non-null    object
#  1   year          220 non-null    object
#  2   percentage    218 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 5.3+ KB

# %%
df_global1.isna().sum()
# Out:
# country_name    0
# year            0
# percentage      2
# dtype: int64

# %%
df_global1.loc[df_global1['percentage'].isna()]
# Out:
#        country_name  year  percentage
# 3    American Samoa  2019         NaN
# 192   Taiwan, China  2019         NaN

# %%
df_global2 = df_global1.dropna()

# %%
import geopandas as gpd
world = gpd.read_file("countries/ne_110m_admin_0_countries.shp")

df2['country_name'] = df2['country_name'].replace({'Tanzania': 'United Republic of Tanzania'})
ea_data = df2.merge(world, left_on='country_name', right_on='SOVEREIGNT', how='left')
geo_ea_data = gpd.GeoDataFrame(ea_data, geometry='geometry')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
geo_ea_data.plot(
    column='percentage', 
    cmap='plasma', 
    legend=True, 
    legend_kwds={'label': "Percentage", 'orientation': "horizontal", 'shrink': 0.5, 'pad': 0.02,},
    ax=ax,
    edgecolor='black'
)

ax.set_title('Percentage of Population with Access to Electricity', fontsize=12, fontweight='bold')
ax.axis('off')
plt.tight_layout(pad=2.0)
plt.savefig('map_ea1.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
df_global2
# Out:
#               country_name  year  percentage
# 0              Afghanistan  2019   97.699997
# 1                  Albania  2019  100.000000
# 2                  Algeria  2019   99.500000
# 4                  Andorra  2019  100.000000
# 5                   Angola  2019   45.642799
# ..                     ...   ...         ...
# 215  Virgin Islands (U.S.)  2019  100.000000
# 216     West Bank and Gaza  2019  100.000000
# 217            Yemen, Rep.  2019   72.751076
# 218                 Zambia  2019   43.000000
# 219               Zimbabwe  2019   46.781475
#
# [218 rows x 3 columns]

# %%
# extracting unique country names
df_countries = set(df_global2['country_name'].unique())
world_countries = set(world['SOVEREIGNT'].unique())

# finding mismatches
print(df_countries)
# Out:
# {'British Virgin Islands', 'Gambia, The', 'Eritrea', 'Nicaragua', 'Cameroon', 'Ukraine', 'Grenada', 'Niger', 'Sierra Leone', 'Armenia', 'San Marino', 'Philippines', 'Tuvalu', 'Cabo Verde', 'Sao Tome and Principe', "Korea, Dem. People's Rep.", 'Turks and Caicos Islands', 'Rwanda', 'Argentina', 'South Sudan', 'New Zealand', 'Ethiopia', 'Andorra', 'Croatia', 'Latvia', 'United Kingdom', 'Denmark', 'Belize', 'Austria', 'Guinea', 'Brunei Darussalam', 'Botswana', 'Solomon Islands', 'Cook Islands', 'Iraq', 'Venezuela, RB', 'Iran, Islamic Rep.', 'Liberia', 'Samoa', 'Guam', 'Zambia', 'Indonesia', 'Ghana', 'India', 'Tajikistan', 'Guyana', 'Bulgaria', 'Curacao', 'Guatemala', 'Kazakhstan', 'Barbados', 'Hong Kong SAR, China', 'Zimbabwe', 'Czech Republic', 'Congo, Rep.', 'Equatorial Guinea', 'Oman', 'Bolivia', 'Belgium', 'Nepal', 'Panama', 'Cayman Islands', 'Trinidad and Tobago', 'French Polynesia', 'Yemen, Rep.', 'Lebanon', 'Georgia', 'Senegal', 'United States', 'Ireland', 'Norway', 'Paraguay', 'P
# ...

# %%
print(world_countries)
# Out:
# {'Ukraine', 'Nicaragua', 'Cameroon', 'Eritrea', 'Niger', 'United States of America', 'Sierra Leone', 'Armenia', 'Yemen', 'Philippines', 'Taiwan', 'Rwanda', 'Argentina', 'South Sudan', 'New Zealand', 'Ethiopia', 'Croatia', 'Latvia', 'United Kingdom', 'Denmark', 'Belize', 'Guinea', 'Austria', 'Botswana', 'Solomon Islands', 'Ivory Coast', 'Iraq', 'Liberia', 'Zambia', 'Indonesia', 'Ghana', 'India', 'South Korea', 'Tajikistan', 'Laos', 'Guyana', 'Bulgaria', 'Costa Rica', 'Kazakhstan', 'Russia', 'Gambia', 'Venezuela', 'Zimbabwe', 'Slovakia', 'Equatorial Guinea', 'Oman', 'Bolivia', 'Panama', 'Nepal', 'Belgium', 'Trinidad and Tobago', 'Lebanon', 'Republic of the Congo', 'Djibouti', 'Georgia', 'Senegal', 'Ireland', 'Norway', 'Portugal', 'Paraguay', 'Brunei', 'Saudi Arabia', 'United Arab Emirates', 'Peru', 'Afghanistan', 'Poland', 'Chad', 'North Macedonia', 'Japan', 'Mauritania', 'Cambodia', 'Cuba', 'Papua New Guinea', 'Iceland', 'Republic of Serbia', 'North Korea', 'Western Sahara', 'Lithuani
# ...

# %%
manual_mapping = {
    "Venezuela, RB": "Venezuela",
    "Congo, Rep.": "Republic of the Congo",
    "United States": "United States of America",
    "Kyrgyz Republic": "Kyrgyzstan",
    "Congo, Dem. Rep.": "Democratic Republic of the Congo",
    "Russian Federation": "Russia",
    "Serbia": "Republic of Serbia",
    "Brunei Darussalam": "Brunei",
    "Korea, Dem. People's Rep.": "North Korea",
    "Iran, Islamic Rep.": "Iran",
    "Eswatini": "eSwatini",
    "Korea, Rep.": "South Korea",
    "Syrian Arab Republic": "Syria",
    "Czech Republic": "Czechia",
    "Slovak Republic": "Slovakia",
    "Cote d'Ivoire": "Ivory Coast",
    "Turkiye": "Turkey",
    "St. Lucia": "Saint Lucia",
    "Bahamas, The": "The Bahamas",
    "Egypt, Arab Rep.": "Egypt",
    "Lao PDR": "Laos",
    "Timor-Leste": "East Timor",
    "Yemen, Rep.": "Yemen",
    "Tanzania": "United Republic of Tanzania",
    "Gambia, The": "Gambia",
    "Micronesia, Fed. Sts.": "Federated States of Micronesia"
}

# %%
df_global2 = df_global2.copy()
df_global2['matched_country'] = df_global2['country_name'].replace(manual_mapping)
df_global2['final_country'] = df_global2['matched_country'].fillna(df_global2['country_name'])

# %%
merged_df = world.merge(df_global2, left_on='SOVEREIGNT', right_on='final_country', how='left')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(12, 6))
merged_df.plot(column='percentage', cmap='coolwarm', legend=True, ax=ax)
plt.title("Choropleth Map of Percentages by Country")
plt.tight_layout(pad=2.0)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
merged_df.plot(
    column='percentage', 
    cmap='Greens', 
    legend=True, 
    legend_kwds={
        'label': "Percentage",
        'orientation': "horizontal",
        'shrink': 0.5,            
        'pad': 0.02,              
    },
    ax=ax,
    edgecolor='black'
)

ax.set_title('Percentage of Population with Access to Electricity', fontsize=12, fontweight='bold')
ax.axis('off')
plt.tight_layout(pad=2.0)
plt.savefig('map5.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import mapclassify

# %%
# creating bins and labels
bins = [0, 25, 50, 75, 101]
labels = ["Below 25%", "25% to 49%", "50% to 74%", "Above 75%"]

merged_df["coverage_bin"] = pd.cut(
    merged_df["percentage"],
    bins=bins,
    labels=labels,
    include_lowest=True  # ensures that 0 is included properly
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
merged_df.plot(
    column="coverage_bin",
    cmap="viridis", #Greens OrRd viridis plasma coolwarm magma
    categorical=True,
    legend=True,
    legend_kwds={
        "title": "Electricity Coverage",
        "loc": "lower left"
    },
    edgecolor="black",
    ax=ax
)
ax.set_title("Percentage of Population with Access to Electricity", fontsize=12, fontweight="bold", pad=20)
ax.text(
    0.5,
    1.02,
    "Source: The World Bank, 2019",
    ha='center',
    va='bottom',
    transform=ax.transAxes,
    fontsize=10,
)

# annotation text
annotation_text = (
    "While most countries enjoy coverage above 75%, Africa particularly in the sub-Sahara, lags behind with many nations having electricity coverage below 50%."
)

# positioning the annotation
ax.text(
    0.5, -65.0,
    annotation_text,
    ha='center',
    va='top',
    fontsize=10,
    bbox=dict(facecolor="white", alpha=0.8, edgecolor="none")
)

ax.axis("off")
plt.tight_layout(pad=2.0)
plt.savefig('electricity_map1.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
merged_df.plot(
    column="coverage_bin",
    cmap="Greens", #Greens OrRd viridis plasma coolwarm magma
    categorical=True,
    legend=True,
    legend_kwds={
        "title": "Electricity Coverage",
        "loc": "lower left"
    },
    edgecolor="black",
    ax=ax
)
ax.set_title("Percentage of Population with Access to Electricity", fontsize=12, fontweight="bold", pad=20)
ax.text(
    0.5,
    1.02,
    "Source: The World Bank, 2019",
    ha='center',
    va='bottom',
    transform=ax.transAxes,
    fontsize=10,
)

# annotation text
annotation_text = (
    "While most countries enjoy coverage above 75%, Africa particularly in the sub-Sahara, lags behind with many nations having electricity coverage below 50%."
)

# positioning the annotation
ax.text(
    0.5, -65.0,
    annotation_text,
    ha='center',
    va='top',
    fontsize=10,
    bbox=dict(facecolor="white", alpha=0.8, edgecolor="none")
)

ax.axis("off")
plt.tight_layout(pad=2.0)
plt.savefig('electricity_map2.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
merged_df.plot(
    column="coverage_bin",
    cmap="magma", #Greens OrRd viridis plasma coolwarm magma
    categorical=True,
    legend=True,
    legend_kwds={
        "title": "Electricity Coverage",
        "loc": "lower left"
    },
    edgecolor="black",
    ax=ax
)
ax.set_title("Percentage of Population with Access to Electricity", fontsize=12, fontweight="bold", pad=20)
ax.text(
    0.5,
    1.02,
    "Source: The World Bank, 2019",
    ha='center',
    va='bottom',
    transform=ax.transAxes,
    fontsize=10,
)

# annotation text
annotation_text = (
    "While most countries enjoy coverage above 75%, Africa particularly in the sub-Sahara, lags behind with many nations having electricity coverage below 50%."
)

# positioning the annotation
ax.text(
    0.5, -65.0,
    annotation_text,
    ha='center',
    va='top',
    fontsize=10,
    bbox=dict(facecolor="white", alpha=0.8, edgecolor="none")
)

ax.axis("off")
plt.tight_layout(pad=2.0)
plt.savefig('electricity_map3.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
print(world.columns)
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'TLC', 'ADMIN',
#        ...
#        'FCLASS_TR', 'FCLASS_ID', 'FCLASS_PL', 'FCLASS_GR', 'FCLASS_IT',
#        'FCLASS_NL', 'FCLASS_SE', 'FCLASS_BD', 'FCLASS_UA', 'geometry'],
#       dtype='object', length=169)

# %%
africa = world[world['CONTINENT'] == 'Africa']

# %%
merged_africa = africa.merge(df_global2, left_on='SOVEREIGNT', right_on='final_country', how='left')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
merged_africa.plot(
    column='percentage', 
    cmap='plasma', 
    legend=True, 
    legend_kwds={
        'label': "Percentage",
        'orientation': "horizontal",
        'shrink': 0.5,            
        'pad': 0.02,              
    },
    ax=ax,
    edgecolor='black'
)

ax.set_title('Percentage of Population with Access to Electricity in African Countries', fontsize=12, fontweight='bold')
ax.axis('off')
plt.tight_layout(pad=2.0)
plt.savefig('map_africa1.png', dpi=600, bbox_inches='tight')
plt.show()
